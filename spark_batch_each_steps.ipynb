# %% [markdown]
# ### **Optional Step if hadoop is not installed**

# %%
# Optional if hadoop is not install in machine
import os
import sys

# 1. Set the path to the folder containing 'bin'
os.environ['HADOOP_HOME'] = "C:\\hadoop"

# 2. Add the bin directory to the system path so Java can find the DLL
sys.path.append("C:\\hadoop\\bin")
os.environ['PATH'] += os.pathsep + "C:\\hadoop\\bin"

# %% [markdown]
# ## **Libraries**

# %%
from pyspark.sql.functions import *
from pyspark.sql import SparkSession
from pyspark.sql.types import *
import os
import sys
import redis
from loguru import logger
import json

# %% [markdown]
# ### **Spark Session**

# %%
# Delta Lake Jar files
# construct Absolute Paths to your JARs
# Get the current directory of the script
current_dir = os.getcwd()
jar_folder = os.path.join(current_dir, "jars")

# Paths to the specific files
delta_core = os.path.join(jar_folder, "delta-core_2.12-2.4.0.jar")
delta_storage = os.path.join(jar_folder, "delta-storage-2.4.0.jar")

# Verify they exist
if not os.path.exists(delta_core):
    print(f"❌ Error: Could not find {delta_core}")
    sys.exit(1)

PACKAGES = "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1"

# %%
spark=(
    SparkSession
    .builder
    .appName('KafkaBatchDebug')
    .config("spark.jars.packages", PACKAGES)
    .config("spark.jars.repositories", "https://repos.spark-packages.org")
    .config('spark.streaming.stopGracefullyOnShutdown',True)
 #   .config('spark.sql.shuffle.partitions',4)
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.4.1") 
    .config("spark.jars", f"{delta_core},{delta_storage}")
    # Delta Configuration
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") 
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.driver.host", "127.0.0.1")
    .master('local[*]')
    .getOrCreate()
)
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://127.0.0.1:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>KafkaBatchDebug</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### **Read Kafka Topic Data**

# %%
kafka_df=spark.read.format('kafka')\
    .option('kafka.bootstrap.servers','localhost:9092')\
    .option('subscribe','raw_transactions')\
    .option('startingOffsets','earliest')\
    .load()

# %%
kafka_df.printSchema()
kafka_df.show()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
#
# +----+--------------------+----------------+---------+------+--------------------+-------------+
# | key|               value|           topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+----------------+---------+------+--------------------+-------------+
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     0|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     1|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     2|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     3|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     4|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     5|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     6|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     7|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     8|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|     9|2025-12-29 16:45:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    10|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    11|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    12|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    13|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    14|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    15|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    16|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    17|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    18|2025-12-29 16:46:...|            0|
# |null|[7B 22 74 72 61 6...|raw_transactions|        0|    19|2025-12-29 16:46:...|            0|
# +----+--------------------+----------------+---------+------+--------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### **Convert value column to proper data**

# %%
kafka_df=kafka_df.withColumn('value',col('value').cast('string'))

# %%
kafka_df.select('value').show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                                                                                                                                                     |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"transaction_id": "9c982496-288b-4739-b960-29a366e52a43", "user_id": 815, "user_name": "Garrett Kim", "amount": 362.92, "currency": "USD", "merchant": "Patterson-Thomas", "location": "Angelatown", "timestamp": 1767006950.7128117}                    |
# |{"transaction_id": "d92fa70e-ba9d-406b-a512-c9006c4a97b4", "user_id": 45, "user_name": "Sarah Diaz", "amount": 63.75, "currency": "USD", "merchant": "Martin-Richards", "location": "Schultzside", "timestamp": 1767006951.7162519}                       |
# |{"transaction_id": "2a2412cb-843d-4ff1-b841-a655566f7baa", "user_id": 49, "user_name": "Lisa Wood", "amount": 471.85, "currency": "USD", "merchant": "Rodriguez-Herrera", "location": "North Amyfort", "timestamp": 1767006952.7221935}                   |
# |{"transaction_id": "cef76480-ba6a-461b-b01f-017bd832d101", "user_id": 480, "user_name": "Brandon Barrera", "amount": 411.37, "currency": "USD", "merchant": "Johnson-Robles", "location": "Port Davidmouth", "timestamp": 1767006953.7276149}             |
# |{"transaction_id": "ae9563c2-794a-4ca0-ba7a-cd1424e8ad21", "user_id": 817, "user_name": "Adam Perry", "amount": 71.0, "currency": "USD", "merchant": "Shepherd, Stout and Murphy", "location": "West Jack", "timestamp": 1767006954.732875}               |
# |{"transaction_id": "e3e2fae2-7e7d-4426-9785-f1e3959ec9d8", "user_id": 436, "user_name": "Dr. Noah Nelson", "amount": 110.33, "currency": "USD", "merchant": "White-Morse", "location": "New Amber", "timestamp": 1767006955.7382224}                      |
# |{"transaction_id": "c3399473-7d61-4ef0-b260-493424b5972e", "user_id": 907, "user_name": "Tammy Mullen DVM", "amount": 44.48, "currency": "USD", "merchant": "Miller, Gonzalez and Castro", "location": "Mitchellborough", "timestamp": 1767006956.7416997}|
# |{"transaction_id": "552d78b4-82d3-4067-b89f-09aca39e887b", "user_id": 65, "user_name": "Allison Howard", "amount": 336.64, "currency": "USD", "merchant": "Fox-Rogers", "location": "North Marcus", "timestamp": 1767006957.7445402}                      |
# |{"transaction_id": "52f9c77e-fdd7-4e1d-af31-2ab2a2787fed", "user_id": 560, "user_name": "Susan James", "amount": 87.51, "currency": "USD", "merchant": "Watson, Short and Ferguson", "location": "Cynthiaport", "timestamp": 1767006958.747467}           |
# |{"transaction_id": "fa9eb0a0-b18e-4077-88de-36923ae0917e", "user_id": 267, "user_name": "Bryce Rush", "amount": 297.34, "currency": "USD", "merchant": "Chambers-Hill", "location": "South Jessica", "timestamp": 1767006959.7536504}                     |
# |{"transaction_id": "10464023-a05c-458e-a563-12ccdc2c618d", "user_id": 492, "user_name": "Daniel Harvey", "amount": 41.02, "currency": "USD", "merchant": "Alexander-Gaines", "location": "Jacksonberg", "timestamp": 1767006960.7574902}                  |
# |{"transaction_id": "c7316aa9-42e8-46b1-9da3-1c47b84de912", "user_id": 19, "user_name": "Brenda White", "amount": 339.95, "currency": "USD", "merchant": "Whitehead, Atkins and Hall", "location": "Port Carmenberg", "timestamp": 1767006961.7613468}     |
# |{"transaction_id": "7c5a8605-2bc8-4436-b759-889e9c44d7f0", "user_id": 376, "user_name": "Donna Hernandez", "amount": 377.05, "currency": "USD", "merchant": "Ramirez Ltd", "location": "East Vicki", "timestamp": 1767006962.7640092}                     |
# |{"transaction_id": "c762e9ba-e244-4ff0-aa6d-fd5a2ee2c633", "user_id": 569, "user_name": "Sonya Villegas", "amount": 196.46, "currency": "USD", "merchant": "Rodriguez Ltd", "location": "Friedmanmouth", "timestamp": 1767006963.7682846}                 |
# |{"transaction_id": "9f0241c2-1bcf-4d39-b915-2cc42fb84b85", "user_id": 467, "user_name": "Michelle Nash", "amount": 58.93, "currency": "USD", "merchant": "Maxwell, Gonzalez and King", "location": "New Gregoryview", "timestamp": 1767006964.7732987}    |
# |{"transaction_id": "584fe35e-d336-4be3-ae74-a3af195c138e", "user_id": 395, "user_name": "Rebecca Neal", "amount": 261.59, "currency": "USD", "merchant": "Wilson, Swanson and Paul", "location": "South Scott", "timestamp": 1767006965.775962}           |
# |{"transaction_id": "aa8c7ddd-74eb-4979-af6f-940fb4959465", "user_id": 628, "user_name": "James Jones", "amount": 468.19, "currency": "USD", "merchant": "Wilson-Lamb", "location": "Meganville", "timestamp": 1767006966.7788763}                         |
# |{"transaction_id": "35893f6f-b8f7-447a-bdbb-15f3d4a08d1f", "user_id": 764, "user_name": "Audrey Mcgee", "amount": 40.39, "currency": "USD", "merchant": "Brooks PLC", "location": "Emilybury", "timestamp": 1767006967.781885}                            |
# |{"transaction_id": "cac7e2a9-cd79-4e28-ace6-ee7e6fafcf1a", "user_id": 938, "user_name": "William Arroyo", "amount": 271.11, "currency": "USD", "merchant": "Ferguson Inc", "location": "North John", "timestamp": 1767006968.783745}                      |
# |{"transaction_id": "b6d67a82-3eb3-4c7e-a288-e587d2493461", "user_id": 339, "user_name": "Daniel Martinez", "amount": 227.43, "currency": "USD", "merchant": "Valencia Ltd", "location": "East Christinaview", "timestamp": 1767006969.7852457}            |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ### **Schema for Json data**

# %%
json_schema=StructType([
    StructField('transaction_id',StringType()),
    StructField('user_id',LongType()),
    StructField('user_name',StringType()),
    StructField('amount',DoubleType()),
    StructField('currency',StringType()),
    StructField('merchant',StringType()),
    StructField('location',StringType()),
    StructField('timestamp',DoubleType()),
])

parsed_df=kafka_df.withColumn('value_json',from_json(col('value'),json_schema)).select('value_json.*')
parsed_df=parsed_df.withColumn('timestamp',to_timestamp((col('timestamp')).cast('long')))
parsed_df.printSchema()
parsed_df.show(truncate=False)
# Out:
# root
#  |-- transaction_id: string (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- user_name: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- merchant: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#
# +------------------------------------+-------+----------------+------+--------+---------------------------+------------------+-------------------+
# |transaction_id                      |user_id|user_name       |amount|currency|merchant                   |location          |timestamp          |
# +------------------------------------+-------+----------------+------+--------+---------------------------+------------------+-------------------+
# |9c982496-288b-4739-b960-29a366e52a43|815    |Garrett Kim     |362.92|USD     |Patterson-Thomas           |Angelatown        |2025-12-29 16:45:50|
# |d92fa70e-ba9d-406b-a512-c9006c4a97b4|45     |Sarah Diaz      |63.75 |USD     |Martin-Richards            |Schultzside       |2025-12-29 16:45:51|
# |2a2412cb-843d-4ff1-b841-a655566f7baa|49     |Lisa Wood       |471.85|USD     |Rodriguez-Herrera          |North Amyfort     |2025-12-29 16:45:52|
# |cef76480-ba6a-461b-b01f-017bd832d101|480    |Brandon Barrera |411.37|USD     |Johnson-Robles             |Port Davidmouth   |2025-12-29 16:45:53|
# |ae9563c2-794a-4ca0-ba7a-cd1424e8ad21|817    |Adam Perry      |71.0  |USD     |Shepherd, Stout and Murphy |West Jack         |2025-12-29 16:45:54|
# |e3e2fae2-7e7d-4426-9785-f1e3959ec9d8|436    |Dr. Noah Nelson |110.33|USD     |White-Morse                |New Amber         |2025-12-29 16:45:55|
# |c3399473-7d61-4ef0-b260-493424b5972e|907    |Tammy Mullen DVM|44.48 |USD     |Miller, Gonzalez and Castro|Mitchellborough   |2025-12-29 16:45:56|
# |552d78b4-82d3-4067-b89f-09aca39e887b|65     |Allison Howard  |336.64|USD     |Fox-Rogers                 |North Marcus      |2025-12-29 16:45:57|
# |52f9c77e-fdd7-4e1d-af31-2ab2a2787fed|560    |Susan James     |87.51 |USD     |Watson, Short and Ferguson |Cynthiaport       |2025-12-29 16:45:58|
# |fa9eb0a0-b18e-4077-88de-36923ae0917e|267    |Bryce Rush      |297.34|USD     |Chambers-Hill              |South Jessica     |2025-12-29 16:45:59|
# |10464023-a05c-458e-a563-12ccdc2c618d|492    |Daniel Harvey   |41.02 |USD     |Alexander-Gaines           |Jacksonberg       |2025-12-29 16:46:00|
# |c7316aa9-42e8-46b1-9da3-1c47b84de912|19     |Brenda White    |339.95|USD     |Whitehead, Atkins and Hall |Port Carmenberg   |2025-12-29 16:46:01|
# |7c5a8605-2bc8-4436-b759-889e9c44d7f0|376    |Donna Hernandez |377.05|USD     |Ramirez Ltd                |East Vicki        |2025-12-29 16:46:02|
# |c762e9ba-e244-4ff0-aa6d-fd5a2ee2c633|569    |Sonya Villegas  |196.46|USD     |Rodriguez Ltd              |Friedmanmouth     |2025-12-29 16:46:03|
# |9f0241c2-1bcf-4d39-b915-2cc42fb84b85|467    |Michelle Nash   |58.93 |USD     |Maxwell, Gonzalez and King |New Gregoryview   |2025-12-29 16:46:04|
# |584fe35e-d336-4be3-ae74-a3af195c138e|395    |Rebecca Neal    |261.59|USD     |Wilson, Swanson and Paul   |South Scott       |2025-12-29 16:46:05|
# |aa8c7ddd-74eb-4979-af6f-940fb4959465|628    |James Jones     |468.19|USD     |Wilson-Lamb                |Meganville        |2025-12-29 16:46:06|
# |35893f6f-b8f7-447a-bdbb-15f3d4a08d1f|764    |Audrey Mcgee    |40.39 |USD     |Brooks PLC                 |Emilybury         |2025-12-29 16:46:07|
# |cac7e2a9-cd79-4e28-ace6-ee7e6fafcf1a|938    |William Arroyo  |271.11|USD     |Ferguson Inc               |North John        |2025-12-29 16:46:08|
# |b6d67a82-3eb3-4c7e-a288-e587d2493461|339    |Daniel Martinez |227.43|USD     |Valencia Ltd               |East Christinaview|2025-12-29 16:46:09|
# +------------------------------------+-------+----------------+------+--------+---------------------------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### **Fraud Transactions**

# %% [markdown]
# #### Amount>10000 fraud

# %%
parsed_df.filter(col('amount')>10000).show()
# Out:
# +--------------------+-------+--------------+--------+--------+--------------------+-------------------+-------------------+
# |      transaction_id|user_id|     user_name|  amount|currency|            merchant|           location|          timestamp|
# +--------------------+-------+--------------+--------+--------+--------------------+-------------------+-------------------+
# |d781e910-a54e-4a8...|    303| Alex Cardenas|10202.35|     USD|         Davis Group|       South Audrey|2025-12-29 16:48:41|
# |c5caec88-56fd-435...|    256|  Gabriel West|19834.11|     USD|Lester, Kirby and...|Lake Jacquelineside|2025-12-29 16:48:48|
# |275b1ad3-ef75-4b9...|    974|   Amber Stein|17270.29|     USD|        Greene Group|  South Diamondfurt|2025-12-29 20:18:33|
# |6ee929a6-8169-400...|    314| Kevin Wallace|11705.97|     USD|    Williams-Jimenez|       Estradamouth|2025-12-29 20:18:40|
# |11459027-8064-41c...|    430|Elizabeth Wade|17598.32|     USD|   Crawford-Martinez|     Port Stephanie|2025-12-29 20:18:43|
# |16ba7007-fed5-45d...|    996|  Hannah Hicks|18975.26|     USD|Moore, Joseph and...|         Reyesmouth|2025-12-29 20:18:44|
# +--------------------+-------+--------------+--------+--------+--------------------+-------------------+-------------------+

# %% [markdown]
# #### Black listed Merchants

# %%
# In production, this would load from a CSV or Database
bad_merchants_data = [
    ("Evil Corp", "High Risk"),
    ("Fake Store Ltd", "Banned"),
    ("Scam Hub", "Under Investigation")
]
schema=['merchant','risk_level']

bad_merchants_df=spark.createDataFrame(data=bad_merchants_data,schema=schema)
bad_merchants_df.show()
# Out:
# +--------------+-------------------+
# |      merchant|         risk_level|
# +--------------+-------------------+
# |     Evil Corp|          High Risk|
# |Fake Store Ltd|             Banned|
# |      Scam Hub|Under Investigation|
# +--------------+-------------------+

# %%
enriched_df=parsed_df.join(broadcast(bad_merchants_df),['merchant'],'left')
enriched_df.show(truncate=False)
# Out:
# +---------------------------+------------------------------------+-------+----------------+------+--------+------------------+-------------------+----------+
# |merchant                   |transaction_id                      |user_id|user_name       |amount|currency|location          |timestamp          |risk_level|
# +---------------------------+------------------------------------+-------+----------------+------+--------+------------------+-------------------+----------+
# |Patterson-Thomas           |9c982496-288b-4739-b960-29a366e52a43|815    |Garrett Kim     |362.92|USD     |Angelatown        |2025-12-29 16:45:50|null      |
# |Martin-Richards            |d92fa70e-ba9d-406b-a512-c9006c4a97b4|45     |Sarah Diaz      |63.75 |USD     |Schultzside       |2025-12-29 16:45:51|null      |
# |Rodriguez-Herrera          |2a2412cb-843d-4ff1-b841-a655566f7baa|49     |Lisa Wood       |471.85|USD     |North Amyfort     |2025-12-29 16:45:52|null      |
# |Johnson-Robles             |cef76480-ba6a-461b-b01f-017bd832d101|480    |Brandon Barrera |411.37|USD     |Port Davidmouth   |2025-12-29 16:45:53|null      |
# |Shepherd, Stout and Murphy |ae9563c2-794a-4ca0-ba7a-cd1424e8ad21|817    |Adam Perry      |71.0  |USD     |West Jack         |2025-12-29 16:45:54|null      |
# |White-Morse                |e3e2fae2-7e7d-4426-9785-f1e3959ec9d8|436    |Dr. Noah Nelson |110.33|USD     |New Amber         |2025-12-29 16:45:55|null      |
# |Miller, Gonzalez and Castro|c3399473-7d61-4ef0-b260-493424b5972e|907    |Tammy Mullen DVM|44.48 |USD     |Mitchellborough   |2025-12-29 16:45:56|null      |
# |Fox-Rogers                 |552d78b4-82d3-4067-b89f-09aca39e887b|65     |Allison Howard  |336.64|USD     |North Marcus      |2025-12-29 16:45:57|null      |
# |Watson, Short and Ferguson |52f9c77e-fdd7-4e1d-af31-2ab2a2787fed|560    |Susan James     |87.51 |USD     |Cynthiaport       |2025-12-29 16:45:58|null      |
# |Chambers-Hill              |fa9eb0a0-b18e-4077-88de-36923ae0917e|267    |Bryce Rush      |297.34|USD     |South Jessica     |2025-12-29 16:45:59|null      |
# |Alexander-Gaines           |10464023-a05c-458e-a563-12ccdc2c618d|492    |Daniel Harvey   |41.02 |USD     |Jacksonberg       |2025-12-29 16:46:00|null      |
# |Whitehead, Atkins and Hall |c7316aa9-42e8-46b1-9da3-1c47b84de912|19     |Brenda White    |339.95|USD     |Port Carmenberg   |2025-12-29 16:46:01|null      |
# |Ramirez Ltd                |7c5a8605-2bc8-4436-b759-889e9c44d7f0|376    |Donna Hernandez |377.05|USD     |East Vicki        |2025-12-29 16:46:02|null      |
# |Rodriguez Ltd              |c762e9ba-e244-4ff0-aa6d-fd5a2ee2c633|569    |Sonya Villegas  |196.46|USD     |Friedmanmouth     |2025-12-29 16:46:03|null      |
# |Maxwell, Gonzalez and King |9f0241c2-1bcf-4d39-b915-2cc42fb84b85|467    |Michelle Nash   |58.93 |USD     |New Gregoryview   |2025-12-29 16:46:04|null      |
# |Wilson, Swanson and Paul   |584fe35e-d336-4be3-ae74-a3af195c138e|395    |Rebecca Neal    |261.59|USD     |South Scott       |2025-12-29 16:46:05|null      |
# |Wilson-Lamb                |aa8c7ddd-74eb-4979-af6f-940fb4959465|628    |James Jones     |468.19|USD     |Meganville        |2025-12-29 16:46:06|null      |
# |Brooks PLC                 |35893f6f-b8f7-447a-bdbb-15f3d4a08d1f|764    |Audrey Mcgee    |40.39 |USD     |Emilybury         |2025-12-29 16:46:07|null      |
# |Ferguson Inc               |cac7e2a9-cd79-4e28-ace6-ee7e6fafcf1a|938    |William Arroyo  |271.11|USD     |North John        |2025-12-29 16:46:08|null      |
# |Valencia Ltd               |b6d67a82-3eb3-4c7e-a288-e587d2493461|339    |Daniel Martinez |227.43|USD     |East Christinaview|2025-12-29 16:46:09|null      |
# +---------------------------+------------------------------------+-------+----------------+------+--------+------------------+-------------------+----------+
# only showing top 20 rows

# %%
final_df=enriched_df.withColumn('is_fraud',when(col('amount')>10000,'Yes').when(col('risk_level').isNotNull(),'Yes').otherwise('No'))\
.withColumn('Reason',when(col('amount')>10000,'High Amount').when(col('risk_level').isNotNull(),'Banned Merchant').otherwise('Normal'))

# %%
fraud_df=final_df.filter(col('is_fraud')=='Yes')
fraud_df.show(truncate=False)
# Out:
# +------------------------+------------------------------------+-------+------------------+--------+--------+-------------------+-------------------+-------------------+--------+---------------+
# |merchant                |transaction_id                      |user_id|user_name         |amount  |currency|location           |timestamp          |risk_level         |is_fraud|Reason         |
# +------------------------+------------------------------------+-------+------------------+--------+--------+-------------------+-------------------+-------------------+--------+---------------+
# |Davis Group             |d781e910-a54e-4a81-a52f-4581543ab00c|303    |Alex Cardenas     |10202.35|USD     |South Audrey       |2025-12-29 16:48:41|null               |Yes     |High Amount    |
# |Lester, Kirby and Ali   |c5caec88-56fd-435b-849a-5590b0f1098e|256    |Gabriel West      |19834.11|USD     |Lake Jacquelineside|2025-12-29 16:48:48|null               |Yes     |High Amount    |
# |Evil Corp               |a34597f7-8d3f-4eac-b222-9d5574db6d09|221    |Jennifer Daniel   |211.22  |USD     |South Kevin        |2025-12-29 20:18:17|High Risk          |Yes     |Banned Merchant|
# |Fake Store Ltd          |a40bfb05-77cb-442a-8b1d-93b9a7dff369|359    |Jessica Davis     |19.81   |USD     |South Heather      |2025-12-29 20:18:20|Banned             |Yes     |Banned Merchant|
# |Fake Store Ltd          |4036e49b-0253-4bab-8795-bf6febaf54b2|813    |Richard Wells     |468.44  |USD     |New Roberttown     |2025-12-29 20:18:27|Banned             |Yes     |Banned Merchant|
# |Greene Group            |275b1ad3-ef75-4b97-b722-5030d6f90be7|974    |Amber Stein       |17270.29|USD     |South Diamondfurt  |2025-12-29 20:18:33|null               |Yes     |High Amount    |
# |Evil Corp               |af5820ad-52f3-4090-b8a8-6ed0146bc2ce|976    |Marie Flores      |306.88  |USD     |Josephmouth        |2025-12-29 20:18:36|High Risk          |Yes     |Banned Merchant|
# |Williams-Jimenez        |6ee929a6-8169-400b-b487-e1101d361014|314    |Kevin Wallace     |11705.97|USD     |Estradamouth       |2025-12-29 20:18:40|null               |Yes     |High Amount    |
# |Fake Store Ltd          |838cd99f-09a5-4994-b4e1-be8d9f7fc2e6|942    |Jeremy Cross      |76.01   |USD     |Wellsside          |2025-12-29 20:18:42|Banned             |Yes     |Banned Merchant|
# |Crawford-Martinez       |11459027-8064-41c7-baac-80f68c8c26b2|430    |Elizabeth Wade    |17598.32|USD     |Port Stephanie     |2025-12-29 20:18:43|null               |Yes     |High Amount    |
# |Moore, Joseph and Barnes|16ba7007-fed5-45db-bded-0aab3a4e21f9|996    |Hannah Hicks      |18975.26|USD     |Reyesmouth         |2025-12-29 20:18:44|null               |Yes     |High Amount    |
# |Fake Store Ltd          |ecf49733-8c2b-4dbe-abf6-5aec98c9c6fa|988    |Brandon Richardson|319.36  |USD     |Jamesshire         |2025-12-29 20:18:45|Banned             |Yes     |Banned Merchant|
# |Scam Hub                |d27c6f57-e5c5-42a3-9665-219658620510|243    |James Kennedy     |83.0    |USD     |Hayeshaven         |2025-12-29 20:18:46|Under Investigation|Yes     |Banned Merchant|
# +------------------------+------------------------------------+-------+------------------+--------+--------+-------------------+-------------------+-------------------+--------+---------------+

# %% [markdown]
# ### **Sink Save everything in deltalake**

# %%
sink_location=os.path.join(os.getcwd(),'lakehouse')

final_df.write.format('delta')\
.mode('append')\
.save(sink_location)

# %% [markdown]
# ### **Sink save fraud transaction in Redis**

# %%
if not fraud_df.isEmpty():
        #count = fraud_df.count()
        #print(f"⚡ Batch {batch_id}: Found {count} fraud alerts! Pushing to Redis...")
        
        try:
            fraud_rows = fraud_df.collect()
            r = redis.Redis(host='localhost', port=6379, db=0)
            
            for row in fraud_rows:
                key = f"fraud:{row.user_id}"
                
                # --- FIX IS HERE ---
                # We generate the current time right now using Python
                # This prevents the "ingest_time not found" error

                fraud_date={
                                'user_id':row.user_id,
                                'user_name':row.user_name,
                                'amount':row.amount,
                                'merchant':row.merchant,
                                'reason':row.Reason
                            }
                
                r.setex(key, 3600, json.dumps(fraud_date))
                
            r.close()
            print(f"   ✅ Successfully pushed {count} alerts.")
            
        except Exception as e:
            print(f"   ❌ Redis Write Failed: {e}")
# Out:
#    ✅ Successfully pushed <function count at 0x00000215052F44A0> alerts.

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
